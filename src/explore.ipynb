# %% [markdown]
# # Explore here

# %%
import requests
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Define the URL
url = "https://raw.githubusercontent.com/4GeeksAcademy/data-preprocessing-project-tutorial/main/AB_NYC_2019.csv"

# Define the folder where you want to save the file
folder_path = os.path.expanduser("/Users/taylorclements/Desktop/Coding")  # Change to your preferred location
file_path = os.path.join(folder_path, "AB_NYC_2019.csv")

# Create the folder if it doesn’t exist
os.makedirs(folder_path, exist_ok=True)

# Download and save the file
response = requests.get(url)
with open(file_path, "wb") as file:
    file.write(response.content)

print(f"File downloaded successfully and saved as {file_path}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       2 import os
#       3 import pandas as pd
# ----> 4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#       8 # Define the URL
#
# File ~/Desktop/Coding_Work/AirBNB/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:1296
#    1292     rcParams['backend_fallback'] = False
#    1295 if os.environ.get('MPLBACKEND'):
# -> 1296     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1299 def get_backend(*, auto_select=True):
#    1300     """
#    1301     Return the name of the current backend.
#    1302
#    (...)
#    1320     matplotlib.use
#    1321     """
#
# File ~/Desktop/Coding_Work/AirBNB/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:771, in RcParams.__setitem__(self, key, val)
#     769         cval = self.validate[key](val)
#     770     except ValueError as ve:
# --> 771         raise ValueError(f"Key {key}: {ve}") from None
#     772     self._set(key, cval)
#     773 except KeyError as err:
#
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
import matplotlib
matplotlib.use("Agg")  # Use a non-interactive backend

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import matplotlib
#       2 matplotlib.use("Agg")  # Use a non-interactive backend
#       4 import matplotlib.pyplot as plt
#
# File ~/Desktop/Coding_Work/AirBNB/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:1296
#    1292     rcParams['backend_fallback'] = False
#    1295 if os.environ.get('MPLBACKEND'):
# -> 1296     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1299 def get_backend(*, auto_select=True):
#    1300     """
#    1301     Return the name of the current backend.
#    1302
#    (...)
#    1320     matplotlib.use
#    1321     """
#
# File ~/Desktop/Coding_Work/AirBNB/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:771, in RcParams.__setitem__(self, key, val)
#     769         cval = self.validate[key](val)
#     770     except ValueError as ve:
# --> 771         raise ValueError(f"Key {key}: {ve}") from None
#     772     self._set(key, cval)
#     773 except KeyError as err:
#
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
df = pd.read_csv(file_path)
print(df.head())  # Display first few rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv(file_path)
#       2 print(df.head())  # Display first few rows
#
# NameError: name 'pd' is not defined

# %%
print(df.shape)  # Display the number of rows and columns
print(df.columns)
# Out:
# (48895, 16)
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df_1 = df.drop(columns=["id", "host_id", "host_name"])

# %%
print(df_1.shape)
# Out:
# (48895, 13)

# %%
df_1.isna().sum()
# Out:
# name                                 16
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df_1[df_1["name"].isna()]
# Out:
#       name neighbourhood_group       neighbourhood  latitude  longitude  \
# 2854   NaN           Manhattan   Battery Park City  40.71239  -74.01620
# 3703   NaN           Manhattan        East Village  40.73215  -73.98821
# 5775   NaN           Manhattan   Greenwich Village  40.73473  -73.99244
# 5975   NaN           Manhattan              Nolita  40.72046  -73.99550
# 6269   NaN            Brooklyn        Williamsburg  40.71370  -73.94378
# 6567   NaN            Brooklyn            Bushwick  40.70046  -73.92825
# 6605   NaN           Manhattan  Washington Heights  40.85198  -73.93108
# 8841   NaN            Brooklyn        Williamsburg  40.71354  -73.93882
# 11963  NaN           Manhattan      Hell's Kitchen  40.76436  -73.98573
# 12824  NaN           Manhattan              Harlem  40.80316  -73.95189
# 13059  NaN           Manhattan           Chinatown  40.71632  -73.99328
# 13401  NaN            Brooklyn         Brownsville  40.66409  -73.92314
# 15819  NaN           Manhattan     Upper West Side  40.79843  -73.96404
# 16071  NaN               Bronx             Fordham  40.86032  -73.88493
# 18047  NaN            Brooklyn  Bedford-Stuyvesant  40.69421  -73.93234
# 28889  NaN            Brooklyn            Bushwick  40.69546  -73.92741
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 2854   Entire home/apt    400            1000                  0         NaN
# 3703   Entire home/apt    200               1                 28  2015-06-08
# 5775   Entire home/apt    225               1                  1  2015-01-01
# 5975   Entire home/apt    215               7                  5  2016-01-02
# 6269      Private room    150               1                  0         NaN
# 6567      Private room     70               1                  0         NaN
# 6605      Private room     40               1                  0         NaN
# 8841      Private room     45               1                  0         NaN
# 11963  Entire home/apt    190               4                  1  2016-01-05
# 12824  Entire home/apt    300               5                  0         NaN
# 13059     Private room     67               4                  0         NaN
# 13401     Private room     50               3                  3  2016-08-18
# 15819     Private room    100               1                  0         NaN
# 16071      Shared room    130               1                  0         NaN
# 18047     Private room     70               3                  0         NaN
# 28889  Entire home/apt    110               4                  5  2018-08-13
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 2854                 NaN                               1               362
# 3703                0.45                               1               341
# 5775                0.02                               1                 0
# 5975                0.09                               1                 0
# 6269                 NaN                               1                 0
# 6567                 NaN                               1                 0
# 6605                 NaN                               1                 0
# 8841                 NaN                               1                 0
# 11963               0.02                               1                 0
# 12824                NaN                               5                 0
# 13059                NaN                               1                 0
# 13401               0.07                               1               362
# 15819                NaN                               2                 0
# 16071                NaN                               1               365
# 18047                NaN                               1                 0
# 28889               0.27                               1                 0

# %%
#looks like it's okay to leave the items with missing values in the name column

df_1.drop("name", axis=1).duplicated().sum()
# Out:
# np.int64(0)

# %%
#Going to remove the long/lat and assume that neighborhood is enough to determine location
df_2 = df_1.drop(columns=["name", "latitude", "longitude"])

print(df_2["calculated_host_listings_count"].value_counts())
# Out:
# calculated_host_listings_count
# 1      32303
# 2       6658
# 3       2853
# 4       1440
# 5        845
# 6        570
# 8        416
# 7        399
# 327      327
# 9        234
# 232      232
# 10       210
# 96       192
# 12       180
# 13       130
# 121      121
# 11       110
# 52       104
# 103      103
# 33        99
# 49        98
# 91        91
# 87        87
# 15        75
# 14        70
# 23        69
# 34        68
# 17        68
# 65        65
# 31        62
# 28        56
# 18        54
# 25        50
# 50        50
# 47        47
# 43        43
# 20        40
# 39        39
# 37        37
# 32        32
# 30        30
# 29        29
# 27        27
# 26        26
# 21        21
# 19        19
# 16        16
# Name: count, dtype: int64

# %% [markdown]
# Interesting. So 32303 out of 48895 are single hosts - 1 property.
# May be worth splitting those up. Or have everyone cut into a few different categories.
#
# The most is 16 properties
#
# column = calculated_host_listings_count

# %%
print(df_2.columns)
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
print(df_2.head())
print(df_2.max(numeric_only=True))
# Out:
#   neighbourhood_group neighbourhood        room_type  price  minimum_nights  \
# 0            Brooklyn    Kensington     Private room    149               1
# 1           Manhattan       Midtown  Entire home/apt    225               1
# 2           Manhattan        Harlem     Private room    150               3
# 3            Brooklyn  Clinton Hill  Entire home/apt     89               1
# 4           Manhattan   East Harlem  Entire home/apt     80              10
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  9  2018-10-19               0.21
# 1                 45  2019-05-21               0.38
# 2                  0         NaN                NaN
# 3                270  2019-07-05               4.64
# 4                  9  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0
# price                             10000.0
# minimum_nights                     1250.0
# number_of_reviews                   629.0
# reviews_per_month                    58.5
# calculated_host_listings_count      327.0
# availability_365                    365.0
# dtype: float64

# %% [markdown]
# Looks like the numerical columns are:
# price, min nights, num reviews, last review, reviews/month, listing count, availability

# %%
#no duplicates in the name column



fig, axis = plt.subplots(3, 2, figsize=(9, 6))

# Create a multiple histogram
sns.histplot(ax = axis[0, 0], data = df_2, x = "price").set_xlim(0, 1000)   # Set the x-axis limits
sns.histplot(ax = axis[0, 1], data = df_2, x = "minimum_nights").set_xlim(0, 30)
sns.histplot(ax = axis[1, 0], data = df_2, x = "number_of_reviews").set(xlim = (0, 300), ylim=(0,4500))  # Set the limits
sns.histplot(ax = axis[1, 1], data = df_2, x = "reviews_per_month").set_xlim(0, 10)
sns.histplot(ax = axis[2, 0], data = df_2, x = "calculated_host_listings_count").set(xlim = (0, 20), ylim=(0, 40000))
sns.histplot(ax = axis[2, 1], data = df_2, x = "availability_365").set_xlim(0, 365)
axis[2,1].set_yscale("log")
# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Let's look at the categorical columns

#I want to make a histogram for the neighborhood group column as it only has 5 areas
sns.histplot(data = df_2, x = "neighbourhood_group")

#
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='Count'>

# %%
#How many different categories of room type are there?
print(df_2["room_type"].nunique())
# Out:
# 3

# %%
#so let's make a histogram for room type now
sns.histplot(data = df_2, x = "room_type")
print(df_2["room_type"].value_counts())
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %% [markdown]
# Just for sake of notes here-
# nummerical data columns: price, min nights, num of reviews, last review, reviews per month, host listing count, availability
#
# categorical data columns: neighbourhood_group, neighbourhood, room type
#
# This is all in df_2

# %%
#Let's make a heatmap to see if there are any correlations between the columns

df_2["neighbourhood_group"] = pd.factorize(df_2["neighbourhood_group"])[0]
df_2["room_type"] = pd.factorize(df_2["room_type"])[0]
#df_2["neighbourhood"] = pd.factorize(df_2["neighbourhood"])[0]

fig, axis = plt.subplots(figsize=(20, 16))

sns.heatmap(df_2[["neighbourhood_group", "room_type", "price", "minimum_nights", "number_of_reviews", "reviews_per_month", "calculated_host_listings_count", "availability_365"]].corr(), annot=True, fmt=".2f", cmap="coolwarm", annot_kws={"size": 25})

axis.set_xticklabels(axis.get_xticklabels(), rotation=45, horizontalalignment="right", fontsize=20)
axis.set_yticklabels(axis.get_yticklabels(), fontsize=20)
# Out:
# [Text(0, 0.5, 'neighbourhood_group'),
#  Text(0, 1.5, 'room_type'),
#  Text(0, 2.5, 'price'),
#  Text(0, 3.5, 'minimum_nights'),
#  Text(0, 4.5, 'number_of_reviews'),
#  Text(0, 5.5, 'reviews_per_month'),
#  Text(0, 6.5, 'calculated_host_listings_count'),
#  Text(0, 7.5, 'availability_365')]

# %%
sns.pairplot(data=df_2[["neighbourhood_group", "room_type", "price", "minimum_nights", "number_of_reviews", "reviews_per_month", "calculated_host_listings_count", "availability_365"]])

# %%
#going to dig a bit deeper into the data now and maybe trim some columns and outliers, etc

df_3 = df_2.drop(columns=["last_review", "reviews_per_month"])

print(df_3.columns)
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#columns that need cleaning/examination: price, min nights, number of reviews, calculated host listings count, availability 365

df_3.describe()
# Out:
#        neighbourhood_group     room_type         price  minimum_nights  \
# count         48895.000000  48895.000000  48895.000000    48895.000000
# mean              0.786911      0.567113    152.720687        7.029962
# std               0.844386      0.541249    240.154170       20.510550
# min               0.000000      0.000000      0.000000        1.000000
# 25%               0.000000      0.000000     69.000000        1.000000
# 50%               1.000000      1.000000    106.000000        3.000000
# 75%               1.000000      1.000000    175.000000        5.000000
# max               4.000000      2.000000  10000.000000     1250.000000
#
#        number_of_reviews  calculated_host_listings_count  availability_365
# count       48895.000000                    48895.000000      48895.000000
# mean           23.274466                        7.143982        112.781327
# std            44.550582                       32.952519        131.622289
# min             0.000000                        1.000000          0.000000
# 25%             1.000000                        1.000000          0.000000
# 50%             5.000000                        1.000000         45.000000
# 75%            24.000000                        2.000000        227.000000
# max           629.000000                      327.000000        365.000000

# %%
#based on this, let's limit price to 500, min nights to 30, number of reviews to 70, calculated host listings count to 10
#, and availability 365 to 365

#just want to look at calculated host listings

print(df_3["calculated_host_listings_count"].value_counts())
# Out:
# calculated_host_listings_count
# 1      32303
# 2       6658
# 3       2853
# 4       1440
# 5        845
# 6        570
# 8        416
# 7        399
# 327      327
# 9        234
# 232      232
# 10       210
# 96       192
# 12       180
# 13       130
# 121      121
# 11       110
# 52       104
# 103      103
# 33        99
# 49        98
# 91        91
# 87        87
# 15        75
# 14        70
# 23        69
# 34        68
# 17        68
# 65        65
# 31        62
# 28        56
# 18        54
# 25        50
# 50        50
# 47        47
# 43        43
# 20        40
# 39        39
# 37        37
# 32        32
# 30        30
# 29        29
# 27        27
# 26        26
# 21        21
# 19        19
# 16        16
# Name: count, dtype: int64

# %%
#let's delete all rows where calculated host listings count is greater than 5

df_4 = df_3[df_3["calculated_host_listings_count"] <= 5]
df_4 = df_4[df_4["price"] <= 500]
df_4 = df_4[df_4["minimum_nights"] <= 15]

# %%
#no duplicates in the name column



fig, axis = plt.subplots(3, 2, figsize=(9, 6))

# Create a multiple histogram
sns.histplot(ax = axis[0, 0], data = df_4, x = "price").set_xlim(0, 500)   # Set the x-axis limits
sns.histplot(ax = axis[0, 1], data = df_4, x = "minimum_nights").set_xlim(0, 15)
sns.histplot(ax = axis[1, 0], data = df_4, x = "number_of_reviews").set(xlim = (0, 150), ylim=(0,4500))  # Set the limits
sns.histplot(ax = axis[2, 0], data = df_4, x = "calculated_host_listings_count").set(xlim = (0, 5), ylim=(0, 30000))
sns.histplot(ax = axis[2, 1], data = df_4, x = "availability_365").set_xlim(0, 365)
axis[2,1].set_yscale("log")
# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
df_4.describe()
# Out:
#        neighbourhood_group     room_type         price  minimum_nights  \
# count         40262.000000  40262.000000  40262.000000    40262.000000
# mean              0.771273      0.543987    130.381178        2.996026
# std               0.865866      0.535554     86.481820        2.497724
# min               0.000000      0.000000      0.000000        1.000000
# 25%               0.000000      0.000000     69.000000        1.000000
# 50%               1.000000      1.000000    100.000000        2.000000
# 75%               1.000000      1.000000    168.000000        4.000000
# max               4.000000      2.000000    500.000000       15.000000
#
#        number_of_reviews  calculated_host_listings_count  availability_365
# count       40262.000000                    40262.000000      40262.000000
# mean           25.512692                        1.441607         91.531990
# std            46.768552                        0.877004        121.117619
# min             0.000000                        1.000000          0.000000
# 25%             1.000000                        1.000000          0.000000
# 50%             6.000000                        1.000000         19.000000
# 75%            27.000000                        2.000000        170.000000
# max           629.000000                        5.000000        365.000000

# %%
#Let's make a heatmap to see if there are any correlations between the columns

df_4["neighbourhood_group"] = pd.factorize(df_4["neighbourhood_group"])[0]
df_4["room_type"] = pd.factorize(df_4["room_type"])[0]
#df_4["neighbourhood"] = pd.factorize(df_4["neighbourhood"])[0]

fig, axis = plt.subplots(figsize=(20, 16))

sns.heatmap(df_4[["neighbourhood_group", "room_type", "price", "minimum_nights", "number_of_reviews", "calculated_host_listings_count", "availability_365"]].corr(), annot=True, fmt=".2f", cmap="coolwarm", annot_kws={"size": 25})

axis.set_xticklabels(axis.get_xticklabels(), rotation=45, horizontalalignment="right", fontsize=20)
axis.set_yticklabels(axis.get_yticklabels(), rotation=0, fontsize=20)
# Out:
# [Text(0, 0.5, 'neighbourhood_group'),
#  Text(0, 1.5, 'room_type'),
#  Text(0, 2.5, 'price'),
#  Text(0, 3.5, 'minimum_nights'),
#  Text(0, 4.5, 'number_of_reviews'),
#  Text(0, 5.5, 'calculated_host_listings_count'),
#  Text(0, 6.5, 'availability_365')]

# %%
df_4.describe()
# Out:
#        neighbourhood_group     room_type         price  minimum_nights  \
# count         40262.000000  40262.000000  40262.000000    40262.000000
# mean              0.791888      0.514132    130.381178        2.996026
# std               0.859136      0.537172     86.481820        2.497724
# min               0.000000      0.000000      0.000000        1.000000
# 25%               0.000000      0.000000     69.000000        1.000000
# 50%               1.000000      0.000000    100.000000        2.000000
# 75%               1.000000      1.000000    168.000000        4.000000
# max               4.000000      2.000000    500.000000       15.000000
#
#        number_of_reviews  calculated_host_listings_count  availability_365
# count       40262.000000                    40262.000000      40262.000000
# mean           25.512692                        1.441607         91.531990
# std            46.768552                        0.877004        121.117619
# min             0.000000                        1.000000          0.000000
# 25%             1.000000                        1.000000          0.000000
# 50%             6.000000                        1.000000         19.000000
# 75%            27.000000                        2.000000        170.000000
# max           629.000000                        5.000000        365.000000
